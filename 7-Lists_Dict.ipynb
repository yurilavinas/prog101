# %% [markdown]
# # Lists
#
# - Lists are used to store multiple items in a single variable
# - Are ordered
# - Can be of any type
#     - Even a combination of different types!
# - Are very flexible
# - Allow duplicates

# %% [markdown]
# - One can build a list using the *list()* constructor
# - or using [], which is the most common way

# %%
list0 = list(("apple", "banana", "cherry")) # note the double round-brackets
print(list0)
# Out:
# ['apple', 'banana', 'cherry']

# %%
list1 = ["apple", "banana", "cherry"]
list2 = [1, 5, 7, 9, 3]
list3 = [True, False, False]

# %%
list1 = ["abc", 34, True, 40, "male"]

# %% [markdown]
# # Operations
# - pop(): to remove an element
# - append(): to add an element at the end

# %%
print(list1)
list1.pop() # pop without any index as parameter removes the last element 
print(list1)
# Out:
# ['abc', 34, True, 40, 'male']
# ['abc', 34, True, 40]

# %%
print(list1)
list1.append(5) # append number 5 at the end 
print(list1)
# Out:
# ['abc', 34, True, 40]
# ['abc', 34, True, 40, 5]

# %%
print(list1)
list1.pop(3) # you can also pop at any index, just give the corret value
# Out:
# ['abc', 34, True, 40, 5]
# 40

# %% [markdown]
# # List Comprehension
#
# List comprehension offers a shorter syntax when you want to create a new list based on the values of an existing list.
#
# - Example:
#
#     - Based on a list of fruits, you want a new list, containing only the fruits with the letter "a" in the name.
#
#     - Without list comprehension you will have to write a for statement with a conditional test inside:

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
newlist = []

for x in fruits:
  if "a" in x:
    newlist.append(x)

print(newlist)
# Out:
# ['apple', 'banana', 'mango']

# %% [markdown]
# - With list comprehension you can do all that with only one line of code!

# %%
newlist = [x for x in fruits if x != "apple"]

# %% [markdown]
# # Methods that can be used with lists
# -  append()	Adds an element at the end of the list
# - clear()	Removes all the elements from the list
# - copy()	Returns a copy of the list
# - count()	Returns the number of elements with the specified value
# - extend()	Add the elements of a list (or any iterable), to the end of the current list
# - index()	Returns the index of the first element with the specified value
# - insert()	Adds an element at the specified position
# - pop()	Removes the element at the specified position
# - remove()	Removes the item with the specified value
# - reverse()	Reverses the order of the list
# - sort()	Sorts the list

# %% [markdown]
# # Let's go online
# https://www.learnpython.org/en/Lists

# %% [markdown]
# # Dictionaries
# - Dictionaries are used to store data values in key:value pairs.
# - They are useful in cases there's a structure to follow: very good for load structured data from datasets, for exemple.

# %%
dreamCar = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
dreamCar
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %% [markdown]
# #### Dictionary are:
# - ordered
# - changeable
# - do not allow duplicates
#
# Dictionary items are presented in key:value pairs, and can be referred to by using the key name.

# %%
dreamCar['model']
# Out:
# 'Mustang'

# %% [markdown]
# - Duplicates aren't allowed, the last one stays:

# %%
dreamCar =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964,
  "year": 2020
}
print(dreamCar)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2020}

# %% [markdown]
# - Actually, I don't like the 2020 model, so let's remove the year's model:.
#
# <!-- ![uglyCar](uglyMustang-1.jpg) -->
# <div>
# <img src="uglyMustang.jpg" width="500"/>
# </div>

# %%
dreamCar.pop("year")
print(dreamCar)
# Out:
# {'brand': 'Ford', 'model': 'Mustang'}

# %% [markdown]
# - Guess what? The model I like is the previous, old value we have already seen:
# <div>
# <img src="blueMustang1694.jpg" width="500"/>
# </div>

# %%
dreamCar["year"] = 1964
print(dreamCar)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %% [markdown]
# - Let's add the color:

# %%
dreamCar["color"] = "blue"
print(dreamCar)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964, 'color': 'blue'}

# %% [markdown]
# But I like more when it's red:
# <div>
# <img src="redMustang1694.jpeg" width="500"/>
# </div>

# %%
dreamCar["color"] = "blue"
print(dreamCar)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964, 'color': 'blue'}

# %% [markdown]
# ## Methods that can be used with dictionaries
#
# - clear()	Removes all the elements from the dictionary
# - copy()	Returns a copy of the dictionary
# - fromkeys()	Returns a dictionary with the specified keys and value
# - get()	Returns the value of the specified key
# - items()	Returns a list containing a tuple for each key value pair
# - keys()	Returns a list containing the dictionary's keys
# - pop()	Removes the element with the specified key
# - popitem()	Removes the last inserted key-value pair
# - setdefault()	Returns the value of the specified key. If the key does not exist: insert the key, with the specified value
# - update()	Updates the dictionary with the specified key-value pairs
# - values()	Returns a list of all the values in the dictionary
