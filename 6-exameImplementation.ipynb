# %% [markdown]
# # Implement the exame you've done

# %% [markdown]
# ## 1 - Max among two numbers
# ### Write a function that takes as input two integers and returns the max

# %% [markdown]
# ## 2 - Max among three numbers
# ### Write a funcion that takes as input three integers and returns the max
# ### (Tip: can you use the function from question one?)

# %% [markdown]
# ## 3 - Executing a function
# ### Consider the following instructions:
# ![image.png](code.png)
#
# ### Detail the execution of function *f* when the input array is equal to (16, 3, 8)
# ### give the value of the variables after each iteration.

# %% [markdown]
# ## 4 - Closest from 0
# ### Write a function that takes as input an array (or list) of intergers which can be either negative or positive and ouputs the value which is the closest from 0.

# %% [markdown]
# ## 5 - Sorted
# ### Write a function that takes as input an array (or list) of intergers which can be either negative or positive and ouputs a boolean value equal to *True* if the integer values are sorted in the ascending order and *false* otherwise.

# %% [markdown]
# ## 6 - Average per line
# ### Write a function that takes as input a 2-dimensional array of integers and returns a 1-dimensional array that contains the average values for each line in the input array.
